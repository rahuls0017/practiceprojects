# %% [markdown]
# ## practice_project_2 --> winedataset.csv

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
#load the data set--> winedataset
df = pd.read_csv("winedataset.csv")
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92         1065
# 1             4.38  1.05           3.40         1050
# ...

# %%
df.tail()
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  diluted wines  Proline
# 173              7.7  0.64           1.74          740
# ...

# %%
df.sample()
# Out:
#     Class  Alcohol  Malic acid  Ash  Alcalinity of ash  Magnesium  \
# 38      1    13.07         1.5  2.1               15.5         98
#
#     Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 38            2.4        2.64                  0.28             1.37
#
#     Color intensity   Hue  diluted wines  Proline
# 38              3.7  1.18           2.69         1020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  diluted wines         178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
# as there is not much difference between the mean and median values. so there are no outliers present. still we will check it further.

# %%
df.Class.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
#there are 3 type of class of wine. wine is our target variable

# %%
df.Class.value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %%
sns.countplot("Class",data = df)

# %% [markdown]
# #class2 has more values as compared to class 1 and 3.

# %%
#find correlation
df_corr = df.corr()
df_corr
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# diluted wines        -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df_corr,annot = True)

# %%
#Total phenols,flavinoids and diluted wines is highly negetively correlated with class.
#Alcanity of ash , Non flavinoid phenols, malic acids are highly positively correlated with class.

# %%
df.plot.box()

# %%
df["Alcohol"].plot.box()

# %%
df["Malic acid"].plot.box()

# %%
df.columns.values
# Out:
# array(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '], dtype=object)

# %%
collist = df.columns.values

# %%
ncols = 14
nrows = 15

# %%
plt.figure(figsize = (13,85))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncols,i+1)
    sns.boxplot(df[collist[i]],color = 'green',orient = 'v')
    plt.tight_layout()

# %%
#some outliers are present in magnesium column.

# %%
plt.figure(figsize=(20,20))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncols,i+1)
    sns.distplot(df[collist[i]])

# %%
df.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.767822
# dtype: float64

# %%
#skewness id accepted in the range (+/-0.5). here malic acid , magnesium,color intensity , proloine are having some skewness.
#malic acid has good correlation with target so we cant drop it proline has high negetive correlation with target so we can't drop it . 
#magnesium and color intensity have weak correlation with target so it can be dropped.

# %%
sns.pairplot(df)

# %%
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
threshold = 3
new_df = df[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (178, 14)

# %%
new_df.shape
# Out:
# (168, 14)

# %%
percentage_loss = (10/178)*100
print(percentage_loss)
# Out:
# 5.617977528089887

# %%
#we can proceed with outlier removal as percenteage loss is less.

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR = q3 - q1
print(IQR)
# Out:
# Class                     2.0000
# Alcohol                   1.3150
# Malic acid                1.4800
# Ash                       0.3475
# Alcalinity of ash         4.3000
# Magnesium                19.0000
# Total phenols             1.0575
# Flavanoids                1.6700
# Nonflavanoid phenols      0.1675
# Proanthocyanins           0.7000
# Color intensity           2.9800
# Hue                       0.3375
# diluted wines             1.2325
# Proline                 484.5000
# dtype: float64

# %%
df_new1 = df[~((df<(q1 - 1.5*IQR))|(df>(q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_new1
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 172      3    14.16        2.51  2.48               20.0         91
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
percentage_loss = (17/178)*100
print(percentage_loss)
# Out:
# 9.550561797752808

# %%
#so we consider z score for removing outlier as loss of data is less.

# %% [markdown]
# #### preparing dataset for model training

# %%
x = new_df.drop('Class',axis = 1)
y = new_df['Class']  #target variable

# %%
#removing skewness
from sklearn.preprocessing import power_transform
x = power_transform(x, method = 'yeo-johnson')

# %% [markdown]
# ### classifier model building

# %%
#Scaling the data using StandardScaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaledx = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(scaledx,y,test_size=.22,random_state = 45)

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
svc= SVC(kernel = "rbf")
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 1.0
# [[11  0  0]
#  [ 0 10  0]
#  [ 0  0 16]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        10
#            3       1.00      1.00      1.00        16
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc = dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.918918918918919
# [[11  0  0]
#  [ 0  9  1]
#  [ 0  2 14]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        11
#            2       0.82      0.90      0.86        10
#            3       0.93      0.88      0.90        16
#
#     accuracy                           0.92        37
#    macro avg       0.92      0.92      0.92        37
# weighted avg       0.92      0.92      0.92        37

# %%
knn= KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn = knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.972972972972973
# [[10  1  0]
#  [ 0 10  0]
#  [ 0  0 16]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.91      0.95        11
#            2       0.91      1.00      0.95        10
#            3       1.00      1.00      1.00        16
#
#     accuracy                           0.97        37
#    macro avg       0.97      0.97      0.97        37
# weighted avg       0.98      0.97      0.97        37

# %%
def svmkernel(ker):
    svc = SVC(kernel = ker)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    predsvc = svc.predict(x_test)
    print(accuracy_score(y_test,predsvc))
    print(confusion_matrix(y_test,predsvc))
    print(classification_report(y_test,predsvc))

# %%
svmkernel('poly')
# Out:
# 0.9459459459459459
# [[10  1  0]
#  [ 0 10  0]
#  [ 0  1 15]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.91      0.95        11
#            2       0.83      1.00      0.91        10
#            3       1.00      0.94      0.97        16
#
#     accuracy                           0.95        37
#    macro avg       0.94      0.95      0.94        37
# weighted avg       0.95      0.95      0.95        37

# %%
svmkernel('linear')
# Out:
# 0.972972972972973
# [[11  0  0]
#  [ 0 10  0]
#  [ 1  0 15]]
#               precision    recall  f1-score   support
#
#            1       0.92      1.00      0.96        11
#            2       1.00      1.00      1.00        10
#            3       1.00      0.94      0.97        16
#
#     accuracy                           0.97        37
#    macro avg       0.97      0.98      0.97        37
# weighted avg       0.98      0.97      0.97        37

# %%
#the best model is SVC with kernel rbf

# %%
from sklearn.model_selection import cross_val_score

dtcscores = cross_val_score(dtc,x,y,cv=5)
print(dtcscores)
print(dtcscores.mean(),dtcscores.std())
# Out:
# [0.82352941 0.94117647 0.88235294 1.         1.        ]
# 0.9294117647058823 0.06859943405700356

# %%
from sklearn.model_selection import cross_val_score

svcscores = cross_val_score(svc,x,y,cv=5)
print(svcscores)
print(svcscores.mean(),svcscores.std())
# Out:
# [0.97058824 0.97058824 1.         0.96969697 0.96969697]
# 0.976114081996435 0.011949608386520046

# %%
from sklearn.model_selection import cross_val_score

knnscores = cross_val_score(knn,x,y,cv=5)
print(knnscores)
print(knnscores.mean(),knnscores.std())
# Out:
# [0.85294118 0.91176471 0.97058824 0.93939394 0.96969697]
# 0.9288770053475937 0.04376250220245011

# %%
#svc is the best model

# %%
from sklearn.model_selection import GridSearchCV 
  
# defining parameter range 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(SVC(), param_grid) 
  
# fitting the model for grid search 
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']})

# %%
# print best parameter after tuning 
print(grid.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# SVC(C=1, gamma=0.01)

# %%
grid_predictions = grid.predict(x_test) 
  
# print classification report 
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        10
#            3       1.00      1.00      1.00        16
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37

# %%
import joblib
joblib.dump(grid.best_estimator_,"winedatasetproject.pkl")
# Out:
# ['winedatasetproject.pkl']
